# %% [markdown]
# # The social network of Caesar's *Bellum Gallicum*

# %% [markdown]
# ## Data Flow
#
# The data will be collected from a reduced version (extracts) of the *Bellum Gallicum*, which has been manually annotated for morphology and syntax according to the Universal Dependency model, in the CoNLL-U format.
#
# See the [GitHub repository](https://github.com/proiel/proiel-treebank/blob/master/caes-gal.conll).

# %% [markdown]
# ### The components of the CoNLL-U annotation schema
#
# CoNLL-U annotations are distributed as plain text files.
#
# The annotation files contain three types of lines: **comment lines**, **word lines** and **blank lines**.
#
# **Comment lines** precede word lines and start with a hash character (#). These lines can be used to provide metadata about the word lines that follow.
#
# Each **word line** contains annotations for a single word or token. Larger linguistic units are represented by subsequent word lines.
#
# The annotations for a word line are provided using the following fields, each separated by a tabulator character:
#
# ```console
# ID	FORM	LEMMA	UPOS	XPOS	FEATS	HEAD	DEPREL	DEPS	MISC
# ```
#
#  1. `ID`: Index of the word in sequence
#  2. `FORM`: The form of a word or punctuation symbol
#  3. `LEMMA`: Lemma or the base form of a word
#  4. `UPOS`: [Universal part-of-speech tag](https://universaldependencies.org/u/pos/)
#  5. `XPOS`: Language-specific part-of-speech tag
#  6. `FEATS`: [Morphological features](https://universaldependencies.org/u/feat/index.html)
#  7. `HEAD`: Syntactic head of the current word
#  8. `DEPREL`: Universal dependency relation to the `HEAD`
#  9. `DEPS`: [Enhanced dependency relations](https://universaldependencies.org/u/overview/enhanced-syntax.html)
#  10. `MISC`: Any additional annotations
#
# Finally, a **blank line** after word lines is used to separate sentences.

# %% [markdown]
# For reading and managing the CoNNL-U formatted file, we will use Python [conllu](https://pypi.org/project/conllu/) library.

# %%
# Import the conllu library
import conllu

# %%
# Open the plain text file for reading; assign under 'data'
with open('caes_gal.conllu', mode="r", encoding="utf-8") as data:

    # Read the file contents and assign under 'annotations'
    annotations = data.read()
# Use the parse() function to parse the annotations; store under 'sentences'
sentences = conllu.parse(annotations)

# %% [markdown]
# The parse() function returns a Python list populated by TokenList objects, native to pyconll library.

# %%
# print the first token (TokenList object) of the first sentence (list).
sentences[0][0]
# Out:
# {'id': 1,
#  'form': 'Gallia',
#  'lemma': 'Gallia',
#  'upos': 'PROPN',
#  'xpos': 'Ne',
#  'feats': {'Case': 'Nom', 'Gender': 'Fem', 'Number': 'Sing'},
#  'head': 4,
#  'deprel': 'nsubj:pass',
#  'deps': None,
#  'misc': {'Ref': '1.1.1'}}

# %% [markdown]
# ### Named Entities extraction
#
# First of all, we want to extract the NE from the annotations. Although proper nouns are already marked as such in `annotations`, we don't need to perform an actual NE recognition. Nevertheless, since sentences are annotated token-by-token, in case of multi-token names we need to group the tokens that are associated with the same entity, i.e. are part of the full name of a character. To do so, we can rely on the consistency of the annotation procedure, for which the "second names" are marked as direct dependants of the "first name" token by a 'flat:name' relation.

# %%
def get_ne(sentences:list):
    full_names = []
    for sent in sentences:
        visited_tokens = []
        for token in sent:
            if token['xpos'] == 'Ne' and token not in visited_tokens:
                second_names = [t for t in sent if t['deprel'] == 'flat:name' and t['head'] == token['id'] and t not in visited_tokens]
                visited_tokens.append(token)
                if second_names:
                    multi_token_name = [token, *second_names] # the token corresponding to the "first name" at the beginning of the list
                    full_names.append(multi_token_name)
                    for t in second_names:
                        visited_tokens.append(t)
                else:
                    full_names.append([token])
    return full_names

# %%
ne_instances = get_ne(sentences)

# %%
ne_tok_instances_set = [l[0] for l in ne_instances]

# %%
ne_tok_instances_set
# Out:
# [{'id': 1,
#   'form': 'Gallia',
#   'lemma': 'Gallia',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 4,
#   'deprel': 'nsubj:pass',
#   'deps': None,
#   'misc': {'Ref': '1.1.1'}},
#  {'id': 4,
#   'form': 'Garumna',
#   'lemma': 'Garumna',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 1,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.1.2'}},
#  {'id': 8,
#   'form': 'Matrona',
#   'lemma': 'Matrona',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 11,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.1.2'}},
#  {'id': 10,
#   'form': 'Sequana',
#   'lemma': 'Sequana',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 8,
#   'deprel': 'conj',
#   'deps': None,
#   'misc': {'Ref': '1.1.2'}},
#  {'id': 36,
#   'form': 'Rhenum',
#   'lemma': 'Rhenus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 37,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.1.4'}},
#  {'id': 8,
#   'form': 'Orgetorix',
#   'lemma': 'Orgetorix',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 4,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.2.1'}},
#  {'id': 2,
#   'form': 'Marco',
#   'lemma': 'Marcus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 6,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.2.1'}},
#  {'id': 4,
#   'form': 'Marco',
#   'lemma': 'Marcus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 2,
#   'deprel': 'conj',
#   'deps': None,
#   'misc': {'Ref': '1.2.1'}},
#  {'id': 8,
#   'form': 'Galliae',
#   'lemma': 'Gallia',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 9,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.2.2'}},
#  {'id': 16,
#   'form': 'Rheno',
#   'lemma': 'Rhenus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 15,
#   'deprel': 'appos',
#   'deps': None,
#   'misc': {'Ref': '1.2.3'}},
#  {'id': 30,
#   'form': 'Iura',
#   'lemma': 'Iura',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 29,
#   'deprel': 'appos',
#   'deps': None,
#   'misc': {'Ref': '1.2.3'}},
#  {'id': 40,
#   'form': 'Lemanno',
#   'lemma': 'Lemannus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 39,
#   'deprel': 'appos',
#   'deps': None,
#   'misc': {'Ref': '1.2.3'}},
#  {'id': 43,
#   'form': 'Rhodano',
#   'lemma': 'Rhodanus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 42,
#   'deprel': 'appos',
#   'deps': None,
#   'misc': {'Ref': '1.2.3'}},
#  {'id': 6,
#   'form': 'Orgetorigis',
#   'lemma': 'Orgetorix',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 5,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.3.1'}},
#  {'id': 5,
#   'form': 'Orgetorix',
#   'lemma': 'Orgetorix',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 6,
#   'deprel': 'nsubj:pass',
#   'deps': None,
#   'misc': {'Ref': '1.3.3'}},
#  {'id': 5,
#   'form': 'Castico',
#   'lemma': 'Casticus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Dat', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 4,
#   'deprel': 'iobj',
#   'deps': None,
#   'misc': {'Ref': '1.3.3'}},
#  {'id': 6,
#   'form': 'Catamantaloedis',
#   'lemma': 'Catamantaloedes',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 7,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.3.3'}},
#  {'id': 3,
#   'form': 'Dumnorigi',
#   'lemma': 'Dumnorix',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Dat', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 22,
#   'deprel': 'iobj',
#   'deps': None,
#   'misc': {'Ref': '1.3.4'}},
#  {'id': 6,
#   'form': 'Diviciaci',
#   'lemma': 'Diviciacus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 5,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.3.4'}},
#  {'id': 21,
#   'form': 'Galliae',
#   'lemma': 'Gallia',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 22,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.3.6'}},
#  {'id': 21,
#   'form': 'Galliae',
#   'lemma': 'Gallia',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 23,
#   'deprel': 'iobj',
#   'deps': None,
#   'misc': {'Ref': '1.3.7'}},
#  {'id': 3,
#   'form': 'Orgetoricem',
#   'lemma': 'Orgetorix',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 8,
#   'deprel': 'obj',
#   'deps': None,
#   'misc': {'Ref': '1.4.1'}},
#  {'id': 5,
#   'form': 'Orgetorix',
#   'lemma': 'Orgetorix',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 16,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.4.2'}},
#  {'id': 19,
#   'form': 'Orgetorix',
#   'lemma': 'Orgetorix',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 20,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.4.3'}},
#  {'id': 25,
#   'form': 'Rhenum',
#   'lemma': 'Rhenus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 26,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.5.3'}},
#  {'id': 32,
#   'form': 'Noreiam',
#   'lemma': 'Noreia',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 34,
#   'deprel': 'obj',
#   'deps': None,
#   'misc': {'Ref': '1.5.3'}},
#  {'id': 9,
#   'form': 'Iuram',
#   'lemma': 'Iura',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 8,
#   'deprel': 'appos',
#   'deps': None,
#   'misc': {'Ref': '1.6.1'}},
#  {'id': 12,
#   'form': 'Rhodanum',
#   'lemma': 'Rhodanus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 11,
#   'deprel': 'appos',
#   'deps': None,
#   'misc': {'Ref': '1.6.1'}},
#  {'id': 20,
#   'form': 'Rhodanus',
#   'lemma': 'Rhodanus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 21,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.6.2'}},
#  {'id': 9,
#   'form': 'Genava',
#   'lemma': 'Genava',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 0,
#   'deprel': 'root',
#   'deps': None,
#   'misc': {'Ref': '1.6.3'}},
#  {'id': 12,
#   'form': 'Rhodani',
#   'lemma': 'Rhodanus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Plur'},
#   'head': 11,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.6.3'}},
#  {'id': 9,
#   'form': 'Lucio',
#   'lemma': 'Lucius',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 13,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.6.3'}},
#  {'id': 11,
#   'form': 'Aulo',
#   'lemma': 'Aulus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 9,
#   'deprel': 'conj',
#   'deps': None,
#   'misc': {'Ref': '1.6.3'}},
#  {'id': 1,
#   'form': 'Caesari',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Dat', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 4,
#   'deprel': 'iobj',
#   'deps': None,
#   'misc': {'Ref': '1.7.1'}},
#  {'id': 23,
#   'form': 'Galliam',
#   'lemma': 'Gallia',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 25,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.7.1'}},
#  {'id': 28,
#   'form': 'Genavam',
#   'lemma': 'Genava',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 29,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.7.1'}},
#  {'id': 12,
#   'form': 'Gallia',
#   'lemma': 'Gallia',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 9,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.7.2'}},
#  {'id': 20,
#   'form': 'Genavam',
#   'lemma': 'Genava',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 16,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.7.2'}},
#  {'id': 17,
#   'form': 'Nammeius',
#   'lemma': 'Nammeius',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 22,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.7.3'}},
#  {'id': 19,
#   'form': 'Verucloetius',
#   'lemma': 'Verucloetius',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 17,
#   'deprel': 'conj',
#   'deps': None,
#   'misc': {'Ref': '1.7.3'}},
#  {'id': 1,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Voc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 21,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.7.3'}},
#  {'id': 5,
#   'form': 'Lucium',
#   'lemma': 'Lucius',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 8,
#   'deprel': 'nsubj:pass',
#   'deps': None,
#   'misc': {'Ref': '1.7.3'}},
#  {'id': 16,
#   'form': 'Lemanno',
#   'lemma': 'Lemannus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 15,
#   'deprel': 'appos',
#   'deps': None,
#   'misc': {'Ref': '1.8.1'}},
#  {'id': 20,
#   'form': 'Rhodanum',
#   'lemma': 'Rhodanus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 19,
#   'deprel': 'appos',
#   'deps': None,
#   'misc': {'Ref': '1.8.1'}},
#  {'id': 24,
#   'form': 'Iuram',
#   'lemma': 'Iura',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 23,
#   'deprel': 'appos',
#   'deps': None,
#   'misc': {'Ref': '1.8.1'}},
#  {'id': 13,
#   'form': 'Rhodani',
#   'lemma': 'Rhodanus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Plur'},
#   'head': 12,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.8.4'}},
#  {'id': 10,
#   'form': 'Dumnorigem',
#   'lemma': 'Dumnorix',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 12,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.9.2'}},
#  {'id': 1,
#   'form': 'Dumnorix',
#   'lemma': 'Dumnorix',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 8,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.9.3'}},
#  {'id': 17,
#   'form': 'Orgetorigis',
#   'lemma': 'Orgetorix',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 18,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.9.3'}},
#  {'id': 1,
#   'form': 'Caesari',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Dat', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 2,
#   'deprel': 'iobj',
#   'deps': None,
#   'misc': {'Ref': '1.10.1'}},
#  {'id': 8,
#   'form': 'Titum',
#   'lemma': 'Titus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 11,
#   'deprel': 'obj',
#   'deps': None,
#   'misc': {'Ref': '1.10.3'}},
#  {'id': 3,
#   'form': 'Italiam',
#   'lemma': 'Italia',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 6,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.10.3'}},
#  {'id': 16,
#   'form': 'Aquileiam',
#   'lemma': 'Aquileia',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 17,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.10.3'}},
#  {'id': 27,
#   'form': 'Galliam',
#   'lemma': 'Gallia',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 24,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.10.3'}},
#  {'id': 29,
#   'form': 'Alpes',
#   'lemma': 'Alpis',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Fem', 'Number': 'Plur'},
#   'head': 24,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.10.3'}},
#  {'id': 6,
#   'form': 'Ocelo',
#   'lemma': 'Ocelum',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Neut', 'Number': 'Sing'},
#   'head': 20,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.10.4'}},
#  {'id': 4,
#   'form': 'Segusiavos',
#   'lemma': 'Seguasivi',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Plur'},
#   'head': 6,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.10.4'}},
#  {'id': 6,
#   'form': 'Rhodanum',
#   'lemma': 'Rhodanus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 7,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.10.4'}},
#  {'id': 13,
#   'form': 'Caesarem',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 14,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.11.2'}},
#  {'id': 10,
#   'form': 'Caesarem',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 12,
#   'deprel': 'obj',
#   'deps': None,
#   'misc': {'Ref': '1.11.3'}},
#  {'id': 5,
#   'form': 'Rhodanum',
#   'lemma': 'Rhodanus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 9,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.11.4'}},
#  {'id': 13,
#   'form': 'Caesarem',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 14,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.11.4'}},
#  {'id': 4,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 8,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.11.5'}},
#  {'id': 3,
#   'form': 'Arar',
#   'lemma': 'Arar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 1,
#   'deprel': 'appos',
#   'deps': None,
#   'misc': {'Ref': '1.12.1'}},
#  {'id': 11,
#   'form': 'Rhodanum',
#   'lemma': 'Rhodanus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 12,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.12.1'}},
#  {'id': 4,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 6,
#   'deprel': 'nsubj:pass',
#   'deps': None,
#   'misc': {'Ref': '1.12.2'}},
#  {'id': 21,
#   'form': 'Ararim',
#   'lemma': 'Arar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 20,
#   'deprel': 'appos',
#   'deps': None,
#   'misc': {'Ref': '1.12.2'}},
#  {'id': 4,
#   'form': 'Tigurinus',
#   'lemma': 'Tigurinus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 3,
#   'deprel': 'xcomp',
#   'deps': None,
#   'misc': {'Ref': '1.12.4'}},
#  {'id': 10,
#   'form': 'Lucium',
#   'lemma': 'Lucius',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 13,
#   'deprel': 'obj',
#   'deps': None,
#   'misc': {'Ref': '1.12.5'}},
#  {'id': 4,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 12,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.12.7'}},
#  {'id': 17,
#   'form': 'Lucii',
#   'lemma': 'Lucius',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 16,
#   'deprel': 'appos',
#   'deps': None,
#   'misc': {'Ref': '1.12.7'}},
#  {'id': 20,
#   'form': 'Lucium',
#   'lemma': 'Lucius',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 28,
#   'deprel': 'obj',
#   'deps': None,
#   'misc': {'Ref': '1.12.7'}},
#  {'id': 23,
#   'form': 'Tigurini',
#   'lemma': 'Tigurinus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Plur'},
#   'head': 28,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.12.7'}},
#  {'id': 27,
#   'form': 'Cassium',
#   'lemma': 'Cassius',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 24,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.12.7'}},
#  {'id': 12,
#   'form': 'Arari',
#   'lemma': 'Arar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 13,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.13.1'}},
#  {'id': 3,
#   'form': 'Divico',
#   'lemma': 'Divico',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 4,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.13.2'}},
#  {'id': 4,
#   'form': 'Caesare',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 5,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.13.3'}},
#  {'id': 18,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 19,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.13.3'}},
#  {'id': 2,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 4,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.14.1'}},
#  {'id': 1,
#   'form': 'Divico',
#   'lemma': 'Divico',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 2,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.14.7'}},
#  {'id': 3,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 2,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.15.1'}},
#  {'id': 1,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 5,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.15.2'}},
#  {'id': 3,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 10,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.16.1'}},
#  {'id': 6,
#   'form': 'Arari',
#   'lemma': 'Arar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 5,
#   'deprel': 'appos',
#   'deps': None,
#   'misc': {'Ref': '1.16.3'}},
#  {'id': 16,
#   'form': 'Arari',
#   'lemma': 'Arar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 18,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.16.3'}},
#  {'id': 26,
#   'form': 'Diviciaco',
#   'lemma': 'Diviciacus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 17,
#   'deprel': 'appos',
#   'deps': None,
#   'misc': {'Ref': '1.16.5'}},
#  {'id': 28,
#   'form': 'Lisco',
#   'lemma': 'Liscus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 26,
#   'deprel': 'conj',
#   'deps': None,
#   'misc': {'Ref': '1.16.5'}},
#  {'id': 3,
#   'form': 'Liscus',
#   'lemma': 'Liscus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 10,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.17.1'}},
#  {'id': 5,
#   'form': 'Caesaris',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 4,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.17.1'}},
#  {'id': 5,
#   'form': 'Galliae',
#   'lemma': 'Gallia',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 4,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.17.3'}},
#  {'id': 25,
#   'form': 'Gallia',
#   'lemma': 'Gallia',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 29,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.17.4'}},
#  {'id': 7,
#   'form': 'Caesari',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Dat', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 8,
#   'deprel': 'iobj',
#   'deps': None,
#   'misc': {'Ref': '1.17.6'}},
#  {'id': 1,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 9,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.18.1'}},
#  {'id': 4,
#   'form': 'Lisci',
#   'lemma': 'Liscus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 3,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.18.1'}},
#  {'id': 5,
#   'form': 'Dumnorigem',
#   'lemma': 'Dumnorix',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 8,
#   'deprel': 'nsubj:pass',
#   'deps': None,
#   'misc': {'Ref': '1.18.1'}},
#  {'id': 6,
#   'form': 'Diviciaci',
#   'lemma': 'Diviciacus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 7,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.18.1'}},
#  {'id': 21,
#   'form': 'Liscum',
#   'lemma': 'Liscus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 22,
#   'deprel': 'obj',
#   'deps': None,
#   'misc': {'Ref': '1.18.1'}},
#  {'id': 3,
#   'form': 'Dumnorigem',
#   'lemma': 'Dumnorix',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 0,
#   'deprel': 'root',
#   'deps': None,
#   'misc': {'Ref': '1.18.3'}},
#  {'id': 12,
#   'form': 'Caesarem',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 8,
#   'deprel': 'obj',
#   'deps': None,
#   'misc': {'Ref': '1.18.8'}},
#  {'id': 22,
#   'form': 'Diviciacus',
#   'lemma': 'Diviciacus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 31,
#   'deprel': 'nsubj:pass',
#   'deps': None,
#   'misc': {'Ref': '1.18.8'}},
#  {'id': 5,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 1,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.18.10'}},
#  {'id': 20,
#   'form': 'Dumnorige',
#   'lemma': 'Dumnorix',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 18,
#   'deprel': 'obl:agent',
#   'deps': None,
#   'misc': {'Ref': '1.18.10'}},
#  {'id': 28,
#   'form': 'Caesari',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Dat', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 30,
#   'deprel': 'iobj',
#   'deps': None,
#   'misc': {'Ref': '1.18.10'}},
#  {'id': 31,
#   'form': 'Dumnorix',
#   'lemma': 'Dumnorix',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 32,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.18.10'}},
#  {'id': 7,
#   'form': 'Diviciaci',
#   'lemma': 'Diviciacus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 13,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.19.2'}},
#  {'id': 5,
#   'form': 'Diviciaci',
#   'lemma': 'Diviciacus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 6,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.19.2'}},
#  {'id': 6,
#   'form': 'Diviciacum',
#   'lemma': 'Diviciacus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 9,
#   'deprel': 'nsubj:pass',
#   'deps': None,
#   'misc': {'Ref': '1.19.3'}},
#  {'id': 16,
#   'form': 'Gaium',
#   'lemma': 'Gaius',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 32,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.19.3'}},
#  {'id': 20,
#   'form': 'Galliae',
#   'lemma': 'Gallia',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 19,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.19.3'}},
#  {'id': 9,
#   'form': 'Dumnorige',
#   'lemma': 'Dumnorix',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 11,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.19.4'}},
#  {'id': 1,
#   'form': 'Diviciacus',
#   'lemma': 'Diviciacus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 8,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.20.1'}},
#  {'id': 5,
#   'form': 'Caesarem',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 6,
#   'deprel': 'obj',
#   'deps': None,
#   'misc': {'Ref': '1.20.1'}},
#  {'id': 26,
#   'form': 'Gallia',
#   'lemma': 'Gallia',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 22,
#   'deprel': 'conj',
#   'deps': None,
#   'misc': {'Ref': '1.20.2'}},
#  {'id': 6,
#   'form': 'Caesare',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 8,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.20.4'}},
#  {'id': 7,
#   'form': 'Galliae',
#   'lemma': 'Gallia',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 8,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.20.4'}},
#  {'id': 7,
#   'form': 'Caesare',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 8,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.20.5'}},
#  {'id': 9,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 12,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.20.5'}},
#  {'id': 1,
#   'form': 'Dumnorigem',
#   'lemma': 'Dumnorix',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 4,
#   'deprel': 'obj',
#   'deps': None,
#   'misc': {'Ref': '1.20.5'}},
#  {'id': 3,
#   'form': 'Diviciaco',
#   'lemma': 'Diviciacus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Dat', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 5,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.20.5'}},
#  {'id': 1,
#   'form': 'Dumnorigi',
#   'lemma': 'Dumnorix',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Dat', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 3,
#   'deprel': 'iobj',
#   'deps': None,
#   'misc': {'Ref': '1.20.5'}},
#  {'id': 4,
#   'form': 'Titum',
#   'lemma': 'Titus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 21,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.21.2'}},
#  {'id': 1,
#   'form': 'Publius',
#   'lemma': 'Publius',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 21,
#   'deprel': 'nsubj:pass',
#   'deps': None,
#   'misc': {'Ref': '1.21.4'}},
#  {'id': 11,
#   'form': 'Lucii',
#   'lemma': 'Lucius',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 10,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.21.4'}},
#  {'id': 16,
#   'form': 'Marci',
#   'lemma': 'Marcus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 10,
#   'deprel': 'conj',
#   'deps': None,
#   'misc': {'Ref': '1.21.4'}},
#  {'id': 7,
#   'form': 'Labieno',
#   'lemma': 'Labienus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 8,
#   'deprel': 'obl:agent',
#   'deps': None,
#   'misc': {'Ref': '1.22.1'}},
#  {'id': 31,
#   'form': 'Labieni',
#   'lemma': 'Labienus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 28,
#   'deprel': 'conj',
#   'deps': None,
#   'misc': {'Ref': '1.22.1'}},
#  {'id': 34,
#   'form': 'Considius',
#   'lemma': 'Considius',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 39,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.22.2'}},
#  {'id': 5,
#   'form': 'Labieno',
#   'lemma': 'Labienus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 6,
#   'deprel': 'obl:agent',
#   'deps': None,
#   'misc': {'Ref': '1.22.2'}},
#  {'id': 1,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 7,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.22.3'}},
#  {'id': 1,
#   'form': 'Labienus',
#   'lemma': 'Labienus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 30,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.22.3'}},
#  {'id': 7,
#   'form': 'Caesare',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 5,
#   'deprel': 'obl:agent',
#   'deps': None,
#   'misc': {'Ref': '1.22.3'}},
#  {'id': 6,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 7,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.22.4'}},
#  {'id': 18,
#   'form': 'Considium',
#   'lemma': 'Considius',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 27,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.22.4'}},
#  {'id': 16,
#   'form': 'Bibracte',
#   'lemma': 'Bibrax',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 28,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.23.1'}},
#  {'id': 7,
#   'form': 'Bibracte',
#   'lemma': 'Bibrax',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 8,
#   'deprel': 'iobj',
#   'deps': None,
#   'misc': {'Ref': '1.23.1'}},
#  {'id': 5,
#   'form': 'Lucii',
#   'lemma': 'Lucius',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 4,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.23.2'}},
#  {'id': 7,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 11,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.24.1'}},
#  {'id': 8,
#   'form': 'Gallia',
#   'lemma': 'Gallia',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 11,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.24.2'}},
#  {'id': 1,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 20,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.25.1'}},
#  {'id': 2,
#   'form': 'Orgetorigis',
#   'lemma': 'Orgetorix',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 3,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.26.4'}},
#  {'id': 1,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 7,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.26.6'}},
#  {'id': 3,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 4,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.27.3'}},
#  {'id': 50,
#   'form': 'Rhenum',
#   'lemma': 'Rhenus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 54,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.27.4'}},
#  {'id': 3,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 4,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.28.1'}},
#  {'id': 21,
#   'form': 'Rhenum',
#   'lemma': 'Rhenus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 22,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.28.3'}},
#  {'id': 32,
#   'form': 'Galliae',
#   'lemma': 'Gallia',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Dat', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 31,
#   'deprel': 'iobj',
#   'deps': None,
#   'misc': {'Ref': '1.28.3'}},
#  {'id': 12,
#   'form': 'Caesarem',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 13,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.29.1'}},
#  {'id': 8,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 9,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.29.3'}},
#  {'id': 6,
#   'form': 'Galliae',
#   'lemma': 'Gallia',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 7,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.30.1'}},
#  {'id': 11,
#   'form': 'Caesarem',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 13,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.30.1'}},
#  {'id': 22,
#   'form': 'Galliae',
#   'lemma': 'Gallia',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 21,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.30.2'}},
#  {'id': 39,
#   'form': 'Galliae',
#   'lemma': 'Gallia',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Dat', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 41,
#   'deprel': 'iobj',
#   'deps': None,
#   'misc': {'Ref': '1.30.3'}},
#  {'id': 55,
#   'form': 'Gallia',
#   'lemma': 'Gallia',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 56,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.30.3'}},
#  {'id': 6,
#   'form': 'Galliae',
#   'lemma': 'Gallia',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 4,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.30.4'}},
#  {'id': 13,
#   'form': 'Caesaris',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 15,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.30.4'}},
#  {'id': 8,
#   'form': 'Ariovistum',
#   'lemma': 'Ariovistus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 10,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.34.1'}},
#  {'id': 3,
#   'form': 'Ariovistus',
#   'lemma': 'Ariovistus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 4,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.34.2'}},
#  {'id': 9,
#   'form': 'Caesare',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 6,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.34.2'}},
#  {'id': 10,
#   'form': 'Galliae',
#   'lemma': 'Gallia',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 9,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.34.3'}},
#  {'id': 14,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 15,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.34.3'}},
#  {'id': 8,
#   'form': 'Gallia',
#   'lemma': 'Gallia',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 19,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.34.4'}},
#  {'id': 13,
#   'form': 'Caesari',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Dat', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 19,
#   'deprel': 'iobj',
#   'deps': None,
#   'misc': {'Ref': '1.34.4'}},
#  {'id': 4,
#   'form': 'Caesarem',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 5,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.35.1'}},
#  {'id': 9,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 14,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.35.1'}},
#  {'id': 8,
#   'form': 'Rhenum',
#   'lemma': 'Rhenus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 11,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.35.3'}},
#  {'id': 10,
#   'form': 'Galliam',
#   'lemma': 'Gallia',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 11,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.35.3'}},
#  {'id': 6,
#   'form': 'Marco',
#   'lemma': 'Marcus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 10,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.35.4'}},
#  {'id': 8,
#   'form': 'Marco',
#   'lemma': 'Marcus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 6,
#   'deprel': 'conj',
#   'deps': None,
#   'misc': {'Ref': '1.35.4'}},
#  {'id': 15,
#   'form': 'Galliam',
#   'lemma': 'Gallia',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 17,
#   'deprel': 'obj',
#   'deps': None,
#   'misc': {'Ref': '1.35.4'}},
#  {'id': 3,
#   'form': 'Ariovistus',
#   'lemma': 'Ariovistus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 4,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.36.1'}},
#  {'id': 2,
#   'form': 'Caesarem',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 4,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.36.4'}},
#  {'id': 3,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 4,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.36.6'}},
#  {'id': 4,
#   'form': 'Caesari',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Dat', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 6,
#   'deprel': 'iobj',
#   'deps': None,
#   'misc': {'Ref': '1.37.1'}},
#  {'id': 8,
#   'form': 'Galliam',
#   'lemma': 'Gallia',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 9,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.37.2'}},
#  {'id': 7,
#   'form': 'Ariovisti',
#   'lemma': 'Ariovistus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 6,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.37.2'}},
#  {'id': 8,
#   'form': 'Rheni',
#   'lemma': 'Rhenus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 7,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.37.3'}},
#  {'id': 11,
#   'form': 'Rhenum',
#   'lemma': 'Rhenus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 12,
#   'deprel': 'obj',
#   'deps': None,
#   'misc': {'Ref': '1.37.3'}},
#  {'id': 3,
#   'form': 'Nasuam',
#   'lemma': 'Nasua',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 2,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.37.3'}},
#  {'id': 5,
#   'form': 'Cimberium',
#   'lemma': 'Cimberius',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 3,
#   'deprel': 'conj',
#   'deps': None,
#   'misc': {'Ref': '1.37.3'}},
#  {'id': 3,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 8,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.37.3'}},
#  {'id': 17,
#   'form': 'Ariovisti',
#   'lemma': 'Ariovistus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 16,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.37.3'}},
#  {'id': 11,
#   'form': 'Ariovistum',
#   'lemma': 'Ariovistus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 12,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.37.4'}},
#  {'id': 8,
#   'form': 'Ariovistum',
#   'lemma': 'Ariovistus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 21,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.38.1'}},
#  {'id': 15,
#   'form': 'Vesontionem',
#   'lemma': 'Vesentio',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 14,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.38.1'}},
#  {'id': 7,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 8,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.38.1'}},
#  {'id': 31,
#   'form': 'Dubis',
#   'lemma': 'Dubis',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 30,
#   'deprel': 'appos',
#   'deps': None,
#   'misc': {'Ref': '1.38.2'}},
#  {'id': 2,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 8,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.38.5'}},
#  {'id': 5,
#   'form': 'Vesontionem',
#   'lemma': 'Vesontio',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 11,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.39.1'}},
#  {'id': 16,
#   'form': 'Caesarem',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 17,
#   'deprel': 'obj',
#   'deps': None,
#   'misc': {'Ref': '1.39.2'}},
#  {'id': 24,
#   'form': 'Ariovistum',
#   'lemma': 'Ariovistus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 22,
#   'deprel': 'conj',
#   'deps': None,
#   'misc': {'Ref': '1.39.6'}},
#  {'id': 4,
#   'form': 'Caesari',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Dat', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 5,
#   'deprel': 'iobj',
#   'deps': None,
#   'misc': {'Ref': '1.39.7'}},
#  {'id': 1,
#   'form': 'Ariovistum',
#   'lemma': 'Ariovistus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 8,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.40.2'}},
#  {'id': 12,
#   'form': 'Gaio',
#   'lemma': 'Gaius',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 14,
#   'deprel': 'obl:agent',
#   'deps': None,
#   'misc': {'Ref': '1.40.5'}},
#  {'id': 5,
#   'form': 'Italia',
#   'lemma': 'Italia',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 1,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '1.40.5'}},
#  {'id': 18,
#   'form': 'Ariovistum',
#   'lemma': 'Ariovistus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 46,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.40.8'}},
#  {'id': 3,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 5,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.40.15'}},
#  {'id': 8,
#   'form': 'Ariovisti',
#   'lemma': 'Ariovistus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 7,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.43.1'}},
#  {'id': 10,
#   'form': 'Caesaris',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 8,
#   'deprel': 'conj',
#   'deps': None,
#   'misc': {'Ref': '1.43.1'}},
#  {'id': 2,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 11,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.43.2'}},
#  {'id': 3,
#   'form': 'Ariovisti',
#   'lemma': 'Ariovistus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 2,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.43.2'}},
#  {'id': 1,
#   'form': 'Ariovistus',
#   'lemma': 'Ariovistus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 13,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.43.3'}},
#  {'id': 5,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 14,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.43.4'}},
#  {'id': 29,
#   'form': 'Galliae',
#   'lemma': 'Gallia',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 30,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '1.43.7'}},
#  {'id': 30,
#   'form': 'Rhenum',
#   'lemma': 'Rhenus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 31,
#   'deprel': 'obj',
#   'deps': None,
#   'misc': {'Ref': '1.43.9'}},
#  {'id': 1,
#   'form': 'Ariovistus',
#   'lemma': 'Ariovistus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 6,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '1.44.1'}},
#  {'id': 4,
#   'form': 'Caesaris',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 3,
#   'deprel': 'nmod',
# ...
#   'head': 11,
#   'deprel': 'appos',
#   'deps': None,
#   'misc': {'Ref': '6.25.2'}},
#  {'id': 6,
#   'form': 'Germaniae',
#   'lemma': 'Germania',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 4,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '6.25.4'}},
#  {'id': 1,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 24,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '6.29.1'}},
#  {'id': 5,
#   'form': 'Gaium',
#   'lemma': 'Gaius',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 9,
#   'deprel': 'obj',
#   'deps': None,
#   'misc': {'Ref': '6.29.3'}},
#  {'id': 8,
#   'form': 'Ambiorigis',
#   'lemma': 'Ambiorix',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 7,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '6.29.4'}},
#  {'id': 11,
#   'form': 'Arduennam',
#   'lemma': 'Arduenna',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 9,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '6.29.4'}},
#  {'id': 13,
#   'form': 'Lucium',
#   'lemma': 'Lucius',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 19,
#   'deprel': 'obj',
#   'deps': None,
#   'misc': {'Ref': '6.29.4'}},
#  {'id': 1,
#   'form': 'Basilus',
#   'lemma': 'Basilus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 5,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '6.30.1'}},
#  {'id': 5,
#   'form': 'Ambiorigem',
#   'lemma': 'Ambiorix',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 6,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '6.30.1'}},
#  {'id': 1,
#   'form': 'Ambiorix',
#   'lemma': 'Ambiorix',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 7,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '6.31.1'}},
#  {'id': 4,
#   'form': 'Arduennam',
#   'lemma': 'Arduenna',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 2,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '6.31.2'}},
#  {'id': 3,
#   'form': 'Oceano',
#   'lemma': 'Oceanus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Dat', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 2,
#   'deprel': 'iobj',
#   'deps': None,
#   'misc': {'Ref': '6.31.3'}},
#  {'id': 1,
#   'form': 'Catuvolcus',
#   'lemma': 'Catuvolcus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 42,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '6.31.5'}},
#  {'id': 9,
#   'form': 'Ambiorige',
#   'lemma': 'Ambiorix',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 11,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '6.31.5'}},
#  {'id': 26,
#   'form': 'Ambiorigem',
#   'lemma': 'Ambiorix',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 25,
#   'deprel': 'obj',
#   'deps': None,
#   'misc': {'Ref': '6.31.5'}},
#  {'id': 36,
#   'form': 'Gallia',
#   'lemma': 'Gallia',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 40,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '6.31.5'}},
#  {'id': 37,
#   'form': 'Germania',
#   'lemma': 'Germania',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 36,
#   'deprel': 'conj',
#   'deps': None,
#   'misc': {'Ref': '6.31.5'}},
#  {'id': 17,
#   'form': 'Caesarem',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 18,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '6.32.1'}},
#  {'id': 33,
#   'form': 'Rhenum',
#   'lemma': 'Rhenus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 29,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '6.32.1'}},
#  {'id': 7,
#   'form': 'Ambiorigi',
#   'lemma': 'Ambiorix',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Dat', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 9,
#   'deprel': 'iobj',
#   'deps': None,
#   'misc': {'Ref': '6.32.1'}},
#  {'id': 1,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 18,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '6.32.2'}},
#  {'id': 10,
#   'form': 'Aduatucam',
#   'lemma': 'Aduatuca',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 11,
#   'deprel': 'iobj',
#   'deps': None,
#   'misc': {'Ref': '6.32.3'}},
#  {'id': 9,
#   'form': 'Titurius',
#   'lemma': 'Titurius',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 14,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '6.32.4'}},
#  {'id': 11,
#   'form': 'Aurunculeius',
#   'lemma': 'Aurunculeius',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 9,
#   'deprel': 'conj',
#   'deps': None,
#   'misc': {'Ref': '6.32.4'}},
#  {'id': 13,
#   'form': 'Italia',
#   'lemma': 'Italia',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 14,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '6.32.5'}},
#  {'id': 5,
#   'form': 'Quintum',
#   'lemma': 'Quintus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 8,
#   'deprel': 'obj',
#   'deps': None,
#   'misc': {'Ref': '6.32.6'}},
#  {'id': 3,
#   'form': 'Titum',
#   'lemma': 'Titus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 17,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '6.33.1'}},
#  {'id': 9,
#   'form': 'Oceanum',
#   'lemma': 'Oceanus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 17,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '6.33.1'}},
#  {'id': 1,
#   'form': 'Gaium',
#   'lemma': 'Gaius',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 14,
#   'deprel': 'obj',
#   'deps': None,
#   'misc': {'Ref': '6.33.2'}},
#  {'id': 7,
#   'form': 'Scaldim',
#   'lemma': 'Scaldis',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 6,
#   'deprel': 'appos',
#   'deps': None,
#   'misc': {'Ref': '6.33.3'}},
#  {'id': 11,
#   'form': 'Mosam',
#   'lemma': 'Mosa',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 9,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '6.33.3'}},
#  {'id': 14,
#   'form': 'Arduennae',
#   'lemma': 'Arduenna',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 15,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '6.33.3'}},
#  {'id': 23,
#   'form': 'Ambiorigem',
#   'lemma': 'Ambiorix',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 22,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '6.33.3'}},
#  {'id': 1,
#   'form': 'Labienum',
#   'lemma': 'Labienus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 4,
#   'deprel': 'obj',
#   'deps': None,
#   'misc': {'Ref': '6.33.5'}},
#  {'id': 2,
#   'form': 'Trebonium',
#   'lemma': 'Trebonius',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 1,
#   'deprel': 'conj',
#   'deps': None,
#   'misc': {'Ref': '6.33.5'}},
#  {'id': 6,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 1,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '6.34.8'}},
#  {'id': 14,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 20,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '6.35.1'}},
#  {'id': 2,
#   'form': 'Rhenum',
#   'lemma': 'Rhenus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 5,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '6.35.4'}},
#  {'id': 9,
#   'form': 'Rheno',
#   'lemma': 'Rhenus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Dat', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 8,
#   'deprel': 'iobj',
#   'deps': None,
#   'misc': {'Ref': '6.35.5'}},
#  {'id': 2,
#   'form': 'Rhenum',
#   'lemma': 'Rhenus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 1,
#   'deprel': 'obj',
#   'deps': None,
#   'misc': {'Ref': '6.35.6'}},
#  {'id': 19,
#   'form': 'Caesare',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 20,
#   'deprel': 'obl:agent',
#   'deps': None,
#   'misc': {'Ref': '6.35.6'}},
#  {'id': 5,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 3,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '6.35.7'}},
#  {'id': 3,
#   'form': 'Atuatucam',
#   'lemma': 'Aduatuca',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 4,
#   'deprel': 'iobj',
#   'deps': None,
#   'misc': {'Ref': '6.35.9'}},
#  {'id': 2,
#   'form': 'Atuatucam',
#   'lemma': 'Aduatuca',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 3,
#   'deprel': 'iobj',
#   'deps': None,
#   'misc': {'Ref': '6.35.10'}},
#  {'id': 1,
#   'form': 'Cicero',
#   'lemma': 'Cicero',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 92,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '6.36.1'}},
#  {'id': 7,
#   'form': 'Caesaris',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 6,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '6.36.1'}},
#  {'id': 31,
#   'form': 'Caesarem',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 33,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '6.36.1'}},
#  {'id': 8,
#   'form': 'Cottae',
#   'lemma': 'Cotta',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 12,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '6.37.8'}},
#  {'id': 11,
#   'form': 'Titurii',
#   'lemma': 'Titurius',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 8,
#   'deprel': 'conj',
#   'deps': None,
#   'misc': {'Ref': '6.37.8'}},
#  {'id': 6,
#   'form': 'Publius',
#   'lemma': 'Publius',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 5,
#   'deprel': 'nsubj:pass',
#   'deps': None,
#   'misc': {'Ref': '6.38.1'}},
#  {'id': 13,
#   'form': 'Caesarem',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 14,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '6.38.1'}},
#  {'id': 3,
#   'form': 'Sextium',
#   'lemma': 'Sextius',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 1,
#   'deprel': 'obj',
#   'deps': None,
#   'misc': {'Ref': '6.38.4'}},
#  {'id': 6,
#   'form': 'Gaio',
#   'lemma': 'Gaius',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 5,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '6.40.4'}},
#  {'id': 20,
#   'form': 'Rhenum',
#   'lemma': 'Rhenus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 22,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '6.41.1'}},
#  {'id': 13,
#   'form': 'Gaius',
#   'lemma': 'Gaius',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 20,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '6.41.2'}},
#  {'id': 27,
#   'form': 'Caesarem',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 24,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '6.41.2'}},
#  {'id': 3,
#   'form': 'Caesaris',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 4,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '6.41.4'}},
#  {'id': 12,
#   'form': 'Rhenum',
#   'lemma': 'Rhenus',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 13,
#   'deprel': 'obj',
#   'deps': None,
#   'misc': {'Ref': '6.42.2'}},
#  {'id': 15,
#   'form': 'Ambiorigis',
#   'lemma': 'Ambiorix',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 16,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '6.42.2'}},
#  {'id': 23,
#   'form': 'Ambiorigi',
#   'lemma': 'Ambiorix',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Dat', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 25,
#   'deprel': 'iobj',
#   'deps': None,
#   'misc': {'Ref': '6.42.2'}},
#  {'id': 1,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 17,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '6.43.1'}},
#  {'id': 19,
#   'form': 'Ambiorigem',
#   'lemma': 'Ambiorix',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 22,
#   'deprel': 'obj',
#   'deps': None,
#   'misc': {'Ref': '6.43.4'}},
#  {'id': 43,
#   'form': 'Caesare',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 44,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '6.43.5'}},
#  {'id': 6,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 12,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '6.44.1'}},
#  {'id': 10,
#   'form': 'Durocortorum',
#   'lemma': 'Durocortorum',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Acc', 'Gender': 'Neut', 'Number': 'Sing'},
#   'head': 12,
#   'deprel': 'iobj',
#   'deps': None,
#   'misc': {'Ref': '6.44.1'}},
#  {'id': 18,
#   'form': 'Galliae',
#   'lemma': 'Gallia',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 17,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '6.44.1'}},
#  {'id': 30,
#   'form': 'Accone',
#   'lemma': 'Acco',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Abl', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 42,
#   'deprel': 'obl',
#   'deps': None,
#   'misc': {'Ref': '6.44.1'}},
#  {'id': 4,
#   'form': 'Galliae',
#   'lemma': 'Gallia',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Gen', 'Gender': 'Fem', 'Number': 'Sing'},
#   'head': 5,
#   'deprel': 'nmod',
#   'deps': None,
#   'misc': {'Ref': '7.3.2'}},
#  {'id': 6,
#   'form': 'Caesar',
#   'lemma': 'Caesar',
#   'upos': 'PROPN',
#   'xpos': 'Ne',
#   'feats': {'Case': 'Nom', 'Gender': 'Masc', 'Number': 'Sing'},
#   'head': 9,
#   'deprel': 'nsubj',
#   'deps': None,
#   'misc': {'Ref': '7.5.3'}}]

# %%
import itertools
from pprint import pprint
from collections import defaultdict

# %%
def get_relations(sentences:list):

    global_relations = []
    # all_full_names = []
    for sent in sentences:
        relations_in_sentence = []
        entities_in_sent = []
        visited_tokens = []
        for token in sent:
            if token['upos'] == 'PROPN' and token not in visited_tokens:
                second_names = [t for t in sent if t['deprel'] == 'flat:name' and t['head'] == token['id'] and t not in visited_tokens]
                visited_tokens.append(token)
                if second_names:
                    fullname = [token, *second_names] # the token corresponding to the "first name" at the beginning of the list
                    # all_full_names.append(fullname)
                    entities_in_sent.append(fullname)
                    for t in second_names:
                        visited_tokens.append(t)
                else:
                    fullname = [token]
                    # all_full_names.append(fullname)
                    entities_in_sent.append(fullname)
                    visited_tokens.append(fullname)

        pairs = list(itertools.combinations(entities_in_sent, 2))

        for pair in pairs:
            ent1 = pair[0]
            ent2 = pair[1]
            distance = 0.5


            if ent1[0]['head'] == ent2[0]['head'] or (ent1[0]['head'] == ent2[0]['id'] or ent2[0]['head'] == ent1[0]['id']):
                distance = 1

            if distance is not None:
                relation = {'ent1':ent1, 'ent2': ent2, 'distance': distance}
                relations_in_sentence.append(relation)

        if relations_in_sentence:
            global_relations.append(relations_in_sentence)

    return global_relations

# %%
relations_instances = get_relations(sentences)

# %% [markdown]
# ## Process relations instances
#
# In the script below, the list of relations, in which each entity's occurence is represented by its TokenList object, is processed to obtain a list of tuples, `final_relations`, each of which consists in the weighted edge of the graph that will be built.

# %%
tmp_relations = []
for rels_in_sent in relations_instances:

    for rel in rels_in_sent:

        ent1 = ' '.join([i['lemma'] for i in rel['ent1']])
        ent2 = ' '.join([i['lemma'] for i in rel['ent2']])

        distance = rel['distance']

        row = (ent1, ent2, distance)
        tmp_relations.append(row)

# create a defaultdict to store the sums
sums = defaultdict(int)

# loop through the tuples and add the third element to the sum
# for the corresponding first two elements
for t in tmp_relations:
    sums[(t[0], t[1])] += t[2]

# create a new list of tuples with the first two elements as the key
# and the sum as the value
final_relations = [(k[0], k[1], v) for k, v in sums.items()]
final_relations = [rel for rel in final_relations if rel[0] != rel[1]]

# %%
final_relations
# Out:
# [('Garumna', 'Matrona', 0.5),
#  ('Garumna', 'Sequana', 0.5),
#  ('Matrona', 'Sequana', 1),
#  ('Marcus Messala', 'Marcus Piso', 2),
#  ('Rhenus', 'Iura', 0.5),
#  ('Rhenus', 'Lemannus', 0.5),
#  ('Rhenus', 'Rhodanus', 0.5),
#  ('Iura', 'Lemannus', 0.5),
#  ('Iura', 'Rhodanus', 1.0),
#  ('Lemannus', 'Rhodanus', 1.5),
#  ('Casticus', 'Catamantaloedes', 0.5),
#  ('Dumnorix', 'Diviciacus', 1.0),
#  ('Rhenus', 'Noreia', 0.5),
#  ('Lucius Piso', 'Aulus Gabinius', 1),
#  ('Caesar', 'Gallia', 7.0),
#  ('Caesar', 'Genava', 0.5),
#  ('Gallia', 'Genava', 1.0),
#  ('Nammeius', 'Verucloetius', 1),
#  ('Caesar', 'Lucius Cassius', 0.5),
#  ('Lemannus', 'Iura', 0.5),
#  ('Rhodanus', 'Iura', 0.5),
#  ('Dumnorix', 'Orgetorix', 0.5),
#  ('Italia', 'Aquileia', 0.5),
#  ('Italia', 'Gallia', 0.5),
#  ('Italia', 'Alpis', 0.5),
#  ('Aquileia', 'Gallia', 0.5),
#  ('Aquileia', 'Alpis', 0.5),
#  ('Gallia', 'Alpis', 1),
#  ('Rhodanus', 'Caesar', 0.5),
#  ('Arar', 'Rhodanus', 0.5),
#  ('Caesar', 'Arar', 0.5),
#  ('Caesar', 'Lucius Piso', 1.0),
#  ('Caesar', 'Tigurinus', 0.5),
#  ('Caesar', 'Cassius', 0.5),
#  ('Lucius Piso', 'Tigurinus', 1.5),
#  ('Lucius Piso', 'Cassius', 1.0),
#  ('Tigurinus', 'Cassius', 0.5),
#  ('Diviciacus', 'Liscus', 1.5),
#  ('Liscus', 'Caesar', 0.5),
#  ('Caesar', 'Liscus', 1.0),
#  ('Caesar', 'Dumnorix', 2.5),
#  ('Caesar', 'Diviciacus', 1.5),
#  ('Liscus', 'Dumnorix', 0.5),
#  ('Liscus', 'Diviciacus', 0.5),
#  ('Dumnorix', 'Liscus', 0.5),
#  ('Dumnorix', 'Caesar', 1.5),
#  ('Diviciacus', 'Gaius Valerius Troucillus', 0.5),
#  ('Diviciacus', 'Gallia', 0.5),
#  ('Gaius Valerius Troucillus', 'Gallia', 0.5),
#  ('Diviciacus', 'Caesar', 0.5),
#  ('Publius Considius', 'Lucius Sulla', 0.5),
#  ('Publius Considius', 'Marcus Crassus', 0.5),
#  ('Lucius Sulla', 'Marcus Crassus', 1),
#  ('Labienus', 'Considius', 1.0),
#  ('Labienus', 'Caesar', 1.0),
#  ('Caesar', 'Considius', 0.5),
#  ('Rhenus', 'Gallia', 2.0),
#  ('Gallia', 'Caesar', 4.0),
#  ('Ariovistus', 'Caesar', 3.0),
#  ('Marcus Messala', 'Gallia', 0.5),
#  ('Marcus Piso', 'Gallia', 0.5),
#  ('Nasua', 'Cimberius', 1),
#  ('Caesar', 'Ariovistus', 2.0),
#  ('Ariovistus', 'Vesentio', 0.5),
#  ('Gallia', 'Ariovistus', 1),
#  ('Quintus', 'Fabius', 1),
#  ('Quintus', 'Maximus', 1),
#  ('Fabius', 'Maximus', 1),
#  ('Ariovistus', 'Gallia', 1.5),
#  ('Gaius Valerius Procillus', 'Gaius Valerius Caburus', 0.5),
#  ('Gaius Valerius Procillus', 'Gaius Valerius', 0.5),
#  ('Gaius Valerius Procillus', 'Ariovistus', 1.0),
#  ('Gaius Valerius Procillus', 'Marcus Metius', 1),
#  ('Gaius Valerius Caburus', 'Gaius Valerius', 0.5),
#  ('Gaius Valerius Caburus', 'Ariovistus', 1.0),
#  ('Gaius Valerius Caburus', 'Marcus Metius', 0.5),
#  ('Gaius Valerius', 'Ariovistus', 1.0),
#  ('Gaius Valerius', 'Marcus Metius', 0.5),
#  ('Ariovistus', 'Marcus Metius', 0.5),
#  ('Marcus Metius', 'Ariovistus', 0.5),
#  ('Ariovistus', 'Voccio', 0.5),
#  ('Voccio', 'Gallia', 0.5),
#  ('Gaius Valerius Procillus', 'Caesar', 1),
#  ('Caesar', 'Iccius', 0.5),
#  ('Caesar', 'Titurius', 1.0),
#  ('Quintus Pedius', 'Lucius Aurunculeius Cotta', 1),
#  ('Caesar', 'Noviodunum', 0.5),
#  ('Caesar', 'Galba', 0.5),
#  ('Bratuspantium', 'Caesar', 1.0),
#  ('Legio', 'Boduognatus', 0.5),
#  ('Caesar', 'Publius Sextius Baculus', 0.5),
#  ('Italia', 'Rhenus', 0.5),
#  ('Publius Crassus', 'Oceanus', 1.0),
#  ('Gallia', 'Rhenus', 1.0),
#  ('Rhenus', 'Caesar', 1.0),
#  ('Caesar', 'Italia', 1.0),
#  ('Caesar', 'Illyricum', 1.0),
#  ('Italia', 'Illyricum', 1),
#  ('Italia', 'Caesar', 1),
#  ('Italia', 'Servius Galba', 0.5),
#  ('Italia', 'Lemannus', 0.5),
#  ('Italia', 'Rhodanus', 0.5),
#  ('Italia', 'Alpes', 0.5),
#  ('Caesar', 'Servius Galba', 0.5),
#  ('Caesar', 'Lemannus', 0.5),
#  ('Caesar', 'Rhodanus', 0.5),
#  ('Caesar', 'Alpes', 0.5),
#  ('Servius Galba', 'Lemannus', 0.5),
#  ('Servius Galba', 'Rhodanus', 0.5),
#  ('Servius Galba', 'Alpes', 0.5),
#  ('Lemannus', 'Alpes', 0.5),
#  ('Rhodanus', 'Alpes', 0.5),
#  ('Galba', 'Octodurus', 0.5),
#  ('Publius Sextius Baculus', 'Gaius Volusenus', 1),
#  ('Publius Sextius Baculus', 'Galba', 1),
#  ('Gaius Volusenus', 'Galba', 0.5),
#  ('Gallia', 'Illyricum', 1.0),
#  ('Illyricum', 'Gallia', 0.5),
#  ('Publius Crassus', 'Andes', 1),
#  ('Oceanus', 'Andes', 0.5),
#  ('Titus Terrasidius', 'Marcus Trebius', 1),
#  ('Titus Terrasidius', 'Coriosolites', 0.5),
#  ('Titus Terrasidius', 'Quintus Velanius', 1),
#  ('Titus Terrasidius', 'Titus Silius', 0.5),
#  ('Marcus Trebius', 'Coriosolites', 1),
#  ('Marcus Trebius', 'Quintus Velanius', 1),
#  ('Marcus Trebius', 'Titus Silius', 0.5),
#  ('Coriosolites', 'Quintus Velanius', 0.5),
#  ('Coriosolites', 'Titus Silius', 0.5),
#  ('Quintus Velanius', 'Titus Silius', 1),
#  ('Silius', 'Velanius', 1),
#  ('Silius', 'Crassus', 0.5),
#  ('Velanius', 'Crassus', 0.5),
#  ('Trebius', 'Terrasidius', 1),
#  ('Caesar', 'Crassus', 0.5),
#  ('Caesar', 'Liger', 0.5),
#  ('Caesar', 'Oceanus', 0.5),
#  ('Crassus', 'Liger', 0.5),
#  ('Crassus', 'Oceanus', 0.5),
#  ('Liger', 'Oceanus', 0.5),
#  ('Venetia', 'Caesar', 0.5),
#  ('Sabinus', 'Caesar', 1.0),
#  ('Sabinus', 'Titurius', 1.0),
#  ('Publius Crassus', 'Aquitania', 0.5),
#  ('Publius Crassus', 'Gallia', 0.5),
#  ('Publius Crassus', 'Lucius Valerius Praeconinus', 0.5),
#  ('Publius Crassus', 'Lucius Manlius', 0.5),
#  ('Aquitania', 'Gallia', 0.5),
#  ('Aquitania', 'Lucius Valerius Praeconinus', 0.5),
#  ('Aquitania', 'Lucius Manlius', 0.5),
#  ('Gallia', 'Lucius Valerius Praeconinus', 0.5),
#  ('Gallia', 'Lucius Manlius', 0.5),
#  ('Lucius Valerius Praeconinus', 'Lucius Manlius', 0.5),
#  ('Tolosa', 'Carcaso', 1),
#  ('Tolosa', 'Narbo', 1),
#  ('Tolosa', 'Gallia', 0.5),
#  ('Carcaso', 'Narbo', 1),
#  ('Carcaso', 'Gallia', 0.5),
#  ('Narbo', 'Gallia', 0.5),
#  ('Adiatunnus', 'Crassus', 1),
#  ('Hispania', 'Aquitania', 1),
#  ('Aquitania', 'Crassus', 0.5),
#  ('Gnaeus Pompeius', 'Marcus Crassus', 1),
#  ('Gnaeus Pompeius', 'Rhenus', 1.0),
#  ('Marcus Crassus', 'Rhenus', 1.0),
#  ('Germania', 'Rhenus', 0.5),
#  ('Caesar', 'Rhenus', 2.0),
#  ('Caesar', 'Britannia', 4.5),
#  ('Gallia', 'Britannia', 1.0),
#  ('Volusenus', 'Caesar', 1),
#  ('Quintus Titurius Sabinus', 'Lucius Aurunculeius Cotta', 1),
#  ('Commius Atrebas', 'Caesar', 0.5),
#  ('Commius Atrebas', 'Britannia', 0.5),
#  ('Britannia', 'Caesar', 1.0),
#  ('Caesar', 'Legio', 0.5),
#  ('Caesar', 'Commius Atrebas', 0.5),
#  ('Caesar', 'Titus Labienus', 1),
#  ('Titus Labienus', 'Britannia', 0.5),
#  ('Quintus Titurius', 'Lucius Cotta', 1),
#  ('Quintus Titurius', 'Caesar', 1),
#  ('Lucius Cotta', 'Caesar', 0.5),
#  ('Lucius Domitius', 'Appius Claudius', 1),
#  ('Lucius Domitius', 'Caesar', 0.5),
#  ('Lucius Domitius', 'Italia', 0.5),
#  ('Appius Claudius', 'Caesar', 0.5),
#  ('Appius Claudius', 'Italia', 0.5),
#  ('Itius', 'Britannia', 0.5),
#  ('Indutiomarus', 'Cingetorix', 1),
#  ('Indutiomarus', 'Arduenna', 0.5),
#  ('Indutiomarus', 'Rhenus', 0.5),
#  ('Arduenna', 'Rhenus', 0.5),
#  ('Cingetorix', 'Caesar', 1.0),
#  ('Cingetorix', 'Indutiomarus', 0.5),
#  ('Caesar', 'Indutiomarus', 1.0),
#  ('Indutiomarus', 'Caesar', 1),
#  ('Caesar', 'Itius', 0.5),
#  ('Caesar', 'Marcus Silanus', 0.5),
#  ('Caesar', 'Gaius Antistius Reginus', 0.5),
#  ('Caesar', 'Titus Sextius', 0.5),
#  ('Gallia', 'Marcus Silanus', 0.5),
#  ('Gallia', 'Gaius Antistius Reginus', 0.5),
#  ('Gallia', 'Titus Sextius', 0.5),
#  ('Marcus Silanus', 'Gaius Antistius Reginus', 1),
#  ('Marcus Silanus', 'Titus Sextius', 1),
#  ('Gaius Antistius Reginus', 'Titus Sextius', 1),
#  ('Gnaeus Pompeius', 'Gallia', 1.0),
#  ('Gnaeus Pompeius', 'Italia', 0.5),
#  ('Gallia', 'Italia', 1.0),
#  ('Pompeius', 'Quintus Titurius', 0.5),
#  ('Gallia', 'Lutecia', 0.5),
#  ('Gallia', 'Ambiorix', 0.5),
#  ('Caesar', 'Gaius Fabius', 0.5),
#  ('Caesar', 'Marcus Crassus', 0.5),
#  ('Gaius Fabius', 'Marcus Crassus', 1),
#  ('Caesar', 'Labienus', 0.5),
#  ('Gallia', 'Germania', 2),
#  ('Diviciacus', 'Roma', 0.5),
#  ('Britannia', 'Gallia', 0.5),
#  ('sol', 'Vulcanus', 1),
#  ('sol', 'luna', 1),
#  ('Vulcanus', 'luna', 1),
#  ('Germania', 'Hercynia', 1),
#  ('Germania', 'Eratosthenes', 0.5),
#  ('Germania', 'Orcynia', 0.5),
#  ('Hercynia', 'Eratosthenes', 0.5),
#  ('Hercynia', 'Orcynia', 0.5),
#  ('Eratosthenes', 'Orcynia', 0.5),
#  ('Ambiorix', 'Arduenna', 0.5),
#  ('Ambiorix', 'Lucius Minucius Basilus', 0.5),
#  ('Arduenna', 'Lucius Minucius Basilus', 0.5),
#  ('Catuvolcus', 'Ambiorix', 1.0),
#  ('Catuvolcus', 'Gallia', 0.5),
#  ('Catuvolcus', 'Germania', 0.5),
#  ('Ambiorix', 'Gallia', 1.0),
#  ('Ambiorix', 'Germania', 1.0),
#  ('Titurius', 'Aurunculeius', 1),
#  ('Titus Labienus', 'Oceanus', 1),
#  ('Scaldis', 'Mosa', 0.5),
#  ('Scaldis', 'Arduenna', 0.5),
#  ('Scaldis', 'Ambiorix', 0.5),
#  ('Mosa', 'Arduenna', 0.5),
#  ('Mosa', 'Ambiorix', 0.5),
#  ('Arduenna', 'Ambiorix', 0.5),
#  ('Labienus', 'Trebonius', 1),
#  ('Cicero', 'Caesar', 1.0),
#  ('Cotta', 'Titurius', 1),
#  ('Publius Sextius Baculus', 'Caesar', 0.5),
#  ('Gaius Volusenus', 'Caesar', 0.5),
#  ('Rhenus', 'Ambiorix', 1.0),
#  ('Ambiorix', 'Caesar', 0.5),
#  ('Caesar', 'Durocortorum', 1),
#  ('Caesar', 'Acco', 0.5),
#  ('Durocortorum', 'Gallia', 0.5),
#  ('Durocortorum', 'Acco', 0.5),
#  ('Gallia', 'Acco', 0.5)]

# %% [markdown]
# #### Create and process the entities that appear in at least one interaction and are actual people

# %%
import json

# create list of entities that are involved in a relation
entities = list(sorted({name for rel in final_relations for name in rel if type(name) == str}))

# assign to a variable the list of all places in Latin literature
# places_list = json.loads('places.json')

with open('places.json') as json_file:
   places_list = json.load(json_file)

# filter entities list
entities = list(filter(lambda x: x not in places_list, entities))

# %%
entities
# Out:
# ['Acco',
#  'Adiatunnus',
#  'Alpis',
#  'Ambiorix',
#  'Andes',
#  'Appius Claudius',
#  'Arduenna',
#  'Ariovistus',
#  'Aulus Gabinius',
#  'Aurunculeius',
#  'Boduognatus',
#  'Bratuspantium',
#  'Caesar',
#  'Carcaso',
#  'Cassius',
#  'Casticus',
#  'Catamantaloedes',
#  'Catuvolcus',
#  'Cicero',
#  'Cimberius',
#  'Cingetorix',
#  'Commius Atrebas',
#  'Considius',
#  'Coriosolites',
#  'Cotta',
#  'Crassus',
#  'Diviciacus',
#  'Dumnorix',
#  'Durocortorum',
#  'Eratosthenes',
#  'Fabius',
#  'Gaius Antistius Reginus',
#  'Gaius Fabius',
#  'Gaius Valerius',
#  'Gaius Valerius Caburus',
#  'Gaius Valerius Procillus',
#  'Gaius Valerius Troucillus',
#  'Gaius Volusenus',
#  'Galba',
#  'Garumna',
#  'Genava',
#  'Gnaeus Pompeius',
#  'Hercynia',
#  'Iccius',
#  'Illyricum',
#  'Indutiomarus',
#  'Itius',
#  'Iura',
#  'Labienus',
#  'Legio',
#  'Lemannus',
#  'Liger',
#  'Liscus',
#  'Lucius Aurunculeius Cotta',
#  'Lucius Cassius',
#  'Lucius Cotta',
#  'Lucius Domitius',
#  'Lucius Manlius',
#  'Lucius Minucius Basilus',
#  'Lucius Piso',
#  'Lucius Sulla',
#  'Lucius Valerius Praeconinus',
#  'Lutecia',
#  'Marcus Crassus',
#  'Marcus Messala',
#  'Marcus Metius',
#  'Marcus Piso',
#  'Marcus Silanus',
#  'Marcus Trebius',
#  'Matrona',
#  'Maximus',
#  'Mosa',
#  'Nammeius',
#  'Narbo',
#  'Nasua',
#  'Noreia',
#  'Noviodunum',
#  'Octodurus',
#  'Orcynia',
#  'Orgetorix',
#  'Pompeius',
#  'Publius Considius',
#  'Publius Crassus',
#  'Publius Sextius Baculus',
#  'Quintus',
#  'Quintus Pedius',
#  'Quintus Titurius',
#  'Quintus Titurius Sabinus',
#  'Quintus Velanius',
#  'Rhenus',
#  'Sabinus',
#  'Scaldis',
#  'Sequana',
#  'Servius Galba',
#  'Silius',
#  'Terrasidius',
#  'Tigurinus',
#  'Titurius',
#  'Titus Labienus',
#  'Titus Sextius',
#  'Titus Silius',
#  'Titus Terrasidius',
#  'Trebius',
#  'Trebonius',
#  'Velanius',
#  'Venetia',
#  'Verucloetius',
#  'Vesentio',
#  'Voccio',
#  'Volusenus',
#  'Vulcanus',
#  'luna',
#  'sol']

# %% [markdown]
# ## Let's build the graph!

# %%
import networkx as nx
from get_relations import final_relations
import matplotlib.pyplot as plt
from networkx.algorithms import community
from pprint import pprint

edges = final_relations
nodes = entities

G = nx.Graph()

for n in nodes:
    G.add_node(n)

for item in final_relations:
    G.add_edge(item[0], item[1], weight=item[2])

# %%
print(G.edges().data())
# Out:
# [('Acco', 'Caesar', {'weight': 0.5}), ('Acco', 'Durocortorum', {'weight': 0.5}), ('Acco', 'Gallia', {'weight': 0.5}), ('Adiatunnus', 'Crassus', {'weight': 1}), ('Alpis', 'Italia', {'weight': 0.5}), ('Alpis', 'Aquileia', {'weight': 0.5}), ('Alpis', 'Gallia', {'weight': 1}), ('Ambiorix', 'Gallia', {'weight': 1.0}), ('Ambiorix', 'Arduenna', {'weight': 0.5}), ('Ambiorix', 'Lucius', {'weight': 0.5}), ('Ambiorix', 'Catuvolcus', {'weight': 1.0}), ('Ambiorix', 'Germania', {'weight': 1.0}), ('Ambiorix', 'Scaldis', {'weight': 0.5}), ('Ambiorix', 'Mosa', {'weight': 0.5}), ('Ambiorix', 'Rhenus', {'weight': 1.0}), ('Ambiorix', 'Caesar', {'weight': 0.5}), ('Andes', 'Publius', {'weight': 1}), ('Andes', 'Oceanus', {'weight': 0.5}), ('Arduenna', 'Indutiomarus', {'weight': 0.5}), ('Arduenna', 'Rhenus', {'weight': 0.5}), ('Arduenna', 'Lucius', {'weight': 0.5}), ('Arduenna', 'Scaldis', {'weight': 0.5}), ('Arduenna', 'Mosa', {'weight': 0.5}), ('Ariovistus', 'Caesar', {'weight': 2.0}), ('Ariovistus', 'Vesentio', {'weight': 0.5}), ('Ariovistus', 'Gallia', {'weight': 1.5}), ('Ariovistus', 'Gaius', {'weight': 3.0}), ('Ariovistus', 'Marcus', {'weight': 0.5}), ('Ariovistus', 'Voccio', {'weight': 0.5}), ('Aurunculeius', 'Titurius', {'weight': 1}), ('Boduognatus', 'Legio', {'weight': 0.5}), ('Bratuspantium', 'Caesar', {'weight': 1.0}), ('Caesar', 'Gallia', {'weight': 4.0}), ('Caesar', 'Genava', {'weight': 0.5}), ('Caesar', 'Lucius', {'weight': 1.0}), ('Caesar', 'Rhodanus', {'weight': 0.5}), ('Caesar', 'Arar', {'weight': 0.5}), ('Caesar', 'Tigurinus', {'weight': 0.5}), ('Caesar', 'Cassius', {'weight': 0.5}), ('Caesar', 'Liscus', {'weight': 1.0}), ('Caesar', 'Dumnorix', {'weight': 1.5}), ('Caesar', 'Diviciacus', {'weight': 0.5}), ('Caesar', 'Labienus', {'weight': 0.5}), ('Caesar', 'Considius', {'weight': 0.5}), ('Caesar', 'Gaius', {'weight': 1.0}), ('Caesar', 'Iccius', {'weight': 0.5}), ('Caesar', 'Titurius', {'weight': 1.0}), ('Caesar', 'Noviodunum', {'weight': 0.5}), ('Caesar', 'Galba', {'weight': 0.5}), ('Caesar', 'Publius', {'weight': 0.5}), ('Caesar', 'Rhenus', {'weight': 2.0}), ('Caesar', 'Italia', {'weight': 1}), ('Caesar', 'Illyricum', {'weight': 1.0}), ('Caesar', 'Servius', {'weight': 0.5}), ('Caesar', 'Lemannus', {'weight': 0.5}), ('Caesar', 'Alpes', {'weight': 0.5}), ('Caesar', 'Crassus', {'weight': 0.5}), ('Caesar', 'Liger', {'weight': 0.5}), ('Caesar', 'Oceanus', {'weight': 0.5}), ('Caesar', 'Venetia', {'weight': 0.5}), ('Caesar', 'Sabinus', {'weight': 1.0}), ('Caesar', 'Britannia', {'weight': 1.0}), ('Caesar', 'Volusenus', {'weight': 1}), ('Caesar', 'Commius', {'weight': 0.5}), ('Caesar', 'Legio', {'weight': 0.5}), ('Caesar', 'Titus', {'weight': 1.5}), ('Caesar', 'Quintus', {'weight': 1}), ('Caesar', 'Appius', {'weight': 0.5}), ('Caesar', 'Cingetorix', {'weight': 1.0}), ('Caesar', 'Indutiomarus', {'weight': 1}), ('Caesar', 'Itius', {'weight': 0.5}), ('Caesar', 'Marcus', {'weight': 1.0}), ('Caesar', 'Cicero', {'weight': 1.0}), ('Caesar', 'Durocortorum', {'weight': 1}), ('Carcaso', 'Tolosa', {'weight': 1}), ('Carcaso', 'Narbo', {'weight': 1}), ('Carcaso', 'Gallia', {'weight': 0.5}), ('Cassius', 'Lucius', {'weight': 1.0}), ('Cassius', 'Tigurinus', {'weight': 0.5}), ('Casticus', 'Catamantaloedes', {'weight': 0.5}), ('Catuvolcus', 'Gallia', {'weight': 0.5}), ('Catuvolcus', 'Germania', {'weight': 0.5}), ('Cimberius', 'Nasua', {'weight': 1}), ('Cingetorix', 'Indutiomarus', {'weight': 0.5}), ('Considius', 'Labienus', {'weight': 1.0}), ('Coriosolites', 'Titus', {'weight': 0.5}), ('Coriosolites', 'Marcus', {'weight': 1}), ('Coriosolites', 'Quintus', {'weight': 0.5}), ('Cotta', 'Titurius', {'weight': 1}), ('Crassus', 'Silius', {'weight': 0.5}), ('Crassus', 'Velanius', {'weight': 0.5}), ('Crassus', 'Liger', {'weight': 0.5}), ('Crassus', 'Oceanus', {'weight': 0.5}), ('Crassus', 'Aquitania', {'weight': 0.5}), ('Diviciacus', 'Dumnorix', {'weight': 1.0}), ('Diviciacus', 'Liscus', {'weight': 0.5}), ('Diviciacus', 'Gaius', {'weight': 0.5}), ('Diviciacus', 'Gall ...

# %%
# VISUALIZATION
# plt.figure(figsize=(15,15))
# nx.draw(G, with_labels=True) # with_labels=True for showing node's label
# plt.show()

# %%
from pyvis.network import Network

net = Network(notebook=True, width="1000px", height="700px", bgcolor="#222222", font_color='white')

net.from_nx(G)
net.show("caes_net.html")
# Out:
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.
#         <iframe
#             width="1000px"
#             height="700px"
#             src="caes_net.html"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
